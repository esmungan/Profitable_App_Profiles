# %% [markdown]
# # Improving App Profitability via Data Analysis
#
# -----------------------------------------------------------------------------
# This project is done as a part of [Python for Data Science: Fundamentals][1] class on DataQuest. Though I have explored beyond what is suggested throughout the project.
#
# * **Concepts learned:** Phyton syntax and fundamental data structures, exposed to Jupiter Notebooks, Github and Kaggle
#
# * **Main challenges** Cleaning up two large datasets with different structures. Analyzing data for skewed or small datasets.
#
# -----------------------------------------------------------------------------
#
# The aim of this project is to provide more insight for developers on what kinds of apps return better profits based on user data. The data to be looked at is for free and English-only apps in IOS and Android markets.
#
# [1]:https://www.dataquest.io/course/python-for-data-science-fundamentals/

# %% [markdown]
# ### 1.Data Review
#
# The very first thing we are going to do is to open the datasets we obtained from the links below. We will look at the content of the data and how it is structured.
# - [Android](https://www.kaggle.com/lava18/google-play-store-apps/home)
#
# - [IOS](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps/home)

# %%
def open_csv (csv_file):
    data_file = open(csv_file)
    from csv import reader
    data_list = list(reader(data_file))
    return data_list

# %%
ios_data = open_csv('AppleStore.csv')
android_data = open_csv('googleplaystore.csv')

# %%
def print_header(string):
    print('#################################################')
    print('#',string)
    print('#################################################\n')

# %%
def explore_data(dataset, source, start, end, rows_and_columns=False):
    string = source+' data samples and dimensions'
    print_header(string)
    
    dataset_slice = dataset[start:end]    
    for row in dataset_slice:
        print(row,'\n')

    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]),'\n')

# %%
explore_data(android_data,'Android', 0, 2, True)
explore_data(ios_data,'IOS', 0, 2, True)
# Out:
# #################################################
# # Android data samples and dimensions
# #################################################
#
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
# Number of rows: 10842
# Number of columns: 13
#
# #################################################
# # IOS data samples and dimensions
# #################################################
#
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
# Number of rows: 7198
# Number of columns: 16

# %% [markdown]
# ### 2. Data Wrangling
#
# In this section we will modify the datasets such that they are accurate and have the right content for our project's scope.
#
# #### 2.1. Missing Columns
#
# The [discussions][1] for the Android  data indicates the Android data has some issues.
#
# First of all, we know that not all entries have the same number of columns. Let us remove the entries with insufficient data. Let us check noth datasets for potentially missing data and remove those entries.
#
# [1]: https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps/discussion

# %%
def check_n_cols(data_list,source):
  
    index = 0
    expected_n_col = len(data_list[0])
    print('Initial number of entries in',source,':', len(data_list))
    for each_row in data_list:
       if len(each_row) != expected_n_col:
        print('At line: ',(index+1), ' number of columns:',len(each_row), ', expected number of columns:', expected_n_col)
        del data_list[index]
       else:
        index += 1
    print('Final number of entries in',source,':', len(data_list), '\n')
    return data_list

# %%
android_data = check_n_cols(android_data,'Android')
ios_data = check_n_cols(ios_data,'IOS')
# Out:
# Initial number of entries in Android : 10842
# At line:  10474  number of columns: 12 , expected number of columns: 13
# Final number of entries in Android : 10841
#
# Initial number of entries in IOS : 7198
# Final number of entries in IOS : 7198

# %% [markdown]
# #### 2.2. Duplicate Entries
#
# Secondly, from the discussions mentioned above we see that there are duplicate entries in the Android dataset. From the checks done below, you will see some of the entries are identical to each other whereas some of them have different number of reviews for the same app.

# %%
def check_identicals(data_list, source):
  
    tuple_list = []                                # Changing the nested lists into nested tuples      
    for each_row in data_list[1:]:                 # so that we can use the set function on them
        tuple_list.append(tuple(each_row))         # lists are not hashable
                            
    data_set = set(tuple_list)                     # set function takes only the unique entries               
    
    if (len(data_set) != (len(data_list)-1)):
        print(source,'dataset has',(len(data_list)-1-len(data_set)),'identical entries \n')
    else:
        print (source,'dataset has NO identical entries')

# %%
check_identicals(android_data,'Android')
check_identicals(ios_data,'IOS')
# Out:
# Android dataset has 483 identical entries
#
# IOS dataset has NO identical entries

# %%
def check_duplicates(data_list, source,name_index):
  
    unique_list =[]
    duplicates_list = []
    
    for each_row in data_list[1:]:  
        app_name = each_row[name_index]
        if(app_name not in unique_list):
            unique_list.append(app_name)
        else:
            duplicates_list.append(app_name)
 
    print(source,'dataset has',len(duplicates_list),'duplicate entries \n')
    return duplicates_list

# %%
def print_samples(data_list, duplicates_list,source, name_index):
    header = 'Sample '+source+' Data:'
    print_header(header)
    print (data_list[0],'\n')
    for each_row in data_list:
        if (each_row[name_index] == duplicates_list[0]):
            print(each_row)
    print('\n')

# %%
android_duplicates = check_duplicates(android_data,'Android',0)
print_samples(android_data,android_duplicates,'Android',0)
        
ios_duplicates = check_duplicates(ios_data,'IOS',1)
print_samples(ios_data,ios_duplicates,'IOS',1)
# Out:
# Android dataset has 1181 duplicate entries
#
# #################################################
# # Sample Android Data:
# #################################################
#
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
# ['Quick PDF Scanner + OCR FREE', 'BUSINESS', '4.2', '80805', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 26, 2018', 'Varies with device', '4.0.3 and up']
# ['Quick PDF Scanner + OCR FREE', 'BUSINESS', '4.2', '80805', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 26, 2018', 'Varies with device', '4.0.3 and up']
# ['Quick PDF Scanner + OCR FREE', 'BUSINESS', '4.2', '80804', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 26, 2018', 'Varies with device', '4.0.3 and up']
#
#
# IOS dataset has 2 duplicate entries
#
# #################################################
# # Sample IOS Data:
# #################################################
#
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
# ['1173990889', 'Mannequin Challenge', '109705216', 'USD', '0.0', '668', '87', '3.0', '3.0', '1.4', '9+', 'Games', '37', '4', '1', '1']
# ['1178454060', 'Mannequin Challenge', '59572224', 'USD', '0.0', '105', '58', '4.0', '4.5', '1.0.1', '4+', 'Games', '38', '5', '1', '1']

# %% [markdown]
# **To cleanup the duplicate entries,** we'll need to select the representative entry for each app. Here, we will assume the entries with the highest number of reviews for a specific app are the latest. Hence, they will be used as the representative content for their corresponding apps.

# %%
def clean_duplicates(data_list,source,name_index,rating_cnt_index):

    unique_dic  = {}
    
    for each_row in data_list[1:]:
        app_name = each_row[name_index]
              
        if (app_name not in unique_dic):
            unique_dic[app_name] = each_row          
        else:
            n_reviews = int(each_row[rating_cnt_index])
            prev_n_reviews = int(unique_dic[app_name][rating_cnt_index])
            if(n_reviews > prev_n_reviews):
                unique_dic[app_name] = each_row          
    
    initial_cnt = len(data_list)
    data_list = [data_list[0]]+list(unique_dic.values())

    n_duplicate = initial_cnt - len(data_list)
    print('Out of',initial_cnt,source,'entries ',n_duplicate, 'have content for the same app name')
    print(source,'data has now',len(data_list),'entries\n')
    return data_list

# %%
android_data = clean_duplicates(android_data,'Android',0,3)
ios_data = clean_duplicates(ios_data,'IOS',1,5)
# Out:
# Out of 10841 Android entries  1181 have content for the same app name
# Android data has now 9660 entries
#
# Out of 7198 IOS entries  2 have content for the same app name
# IOS data has now 7196 entries

# %% [markdown]
# #### 2.3. Remove Non-English Content
#
# On the third step, we will remove the content for apps that are not in English since our scope is limited to the American market.
#
# To detect wheter an app name is in English we will look at the ASCII codes of the characters within the app's name. English characters have ASCII codes less than 128. So any character below this value should be at least written in Latin alphabet and would probably (not surely) in English.
#
# There are couple of corner cases this algorithm doesn't work though. Superscripts and emojis that we have encountered in our datasets have ASCII codes larger than 127 and they don't follow an easy-to-detect pattern. Hence, we will allow a certain number of characters with ASCII codes higher than 127 in our definition of what goes into an English word. As you can expect this algorithm is not bullet-proof.

# %%
def is_english(string, tolerance,verbose = False):
    english = True
    counter = 0
    for each_char in (string):
        if (ord(each_char) > 127) :     
            counter += 1
            if counter > tolerance:
                english = False
    if verbose : print(string,' is English?',english) 
    return english

# %% [markdown]
# Let us test the above function on following test cases:

# %%
a = 'Docs To Go™ Free Office Suite'
b = 'Instachat 😜'
c = '爱奇艺PPS -《欢乐颂2》电视剧热播'

for test_case in [a,b,c]:
    is_english (test_case,2,True)
# Out:
# Docs To Go™ Free Office Suite  is English? True
# Instachat 😜  is English? True
# 爱奇艺PPS -《欢乐颂2》电视剧热播  is English? False

# %%
def pick_eng_apps (data_list, source, name_index, tolerance, verbose = False):
    index = 1
    ne_app_names = []
    initial_cnt = len(data_list)
    
    for each_row in data_list[1:]:
        app_name = each_row[name_index]
        
        if not(is_english(app_name,tolerance)):
            ne_app_names.append(app_name)
            del data_list[index]
        else:
            index += 1

    n_neng = initial_cnt-len(data_list)
    print('Out of',initial_cnt,source,'entries ',n_neng, 'have non-English content for a tolerance of',tolerance,'characters')
    print(source,'data has now',len(data_list),'entries\n')
    
    if verbose: print(ne_app_names,'\n')
    return data_list

# %% [markdown]
# **You can play with the following code piece** to see what non-English app names the we catch for a given tolerance level (default is 3 characters).

# %%
tolerance = 3 
verbose = False    #change to 'True' to see the list of non-English app names
android_data = pick_eng_apps(android_data,'Android',0,tolerance,verbose)
ios_data = pick_eng_apps(ios_data,'IOS',1,tolerance,verbose)
# Out:
# Out of 9660 Android entries  45 have non-English content for a tolerance of 3 characters
# Android data has now 9615 entries
#
# Out of 7196 IOS entries  1014 have non-English content for a tolerance of 3 characters
# IOS data has now 6182 entries

# %% [markdown]
# #### 2.4. Pick Free Apps
#
# As the final step, we will remove the data for paid apps from our dataset. To do that, we will look at the price of the apps and remove the ones that are not zero.

# %%
def pick_free_apps (data_list,source,price_index):
    index = 1 
    initial_cnt = len(data_list)
    for each_row in data_list[1:]:
        price = each_row[price_index]
        if ((price != '0.0') and (price != '0')) :
            del data_list[index]
        else:
            index += 1
    
    print('Out of',initial_cnt,source,'entries ',initial_cnt-len(data_list), 'are for paid apps')
    print(source,'data has now',len(data_list),'entries\n')
    return data_list

# %%
android_data = pick_free_apps(android_data,'Android',7)
ios_data = pick_free_apps(ios_data,'IOS',4)
# Out:
# Out of 9615 Android entries  750 are for paid apps
# Android data has now 8865 entries
#
# Out of 6182 IOS entries  2961 are for paid apps
# IOS data has now 3221 entries

# %% [markdown]
# ### 3. Data Analysis
#
# In this section we will look at the finally clean datasets and try to deduce patterns for popularity and hence the profitability of an app genre.
#
# #### 3.1. Ranking with respect to Number of Apps in Store
#
# Let us first look at which type of genres has the most number of apps provided at the app store. To do that we will need to create some frequency tables and sort them in a descending order.

# %%
def freq_table (data_list, index):
    
    total = len(data_list)-1
    f_table = {}
    
    for each_row in data_list[1:]:
        key = each_row [index]
        
        if key not in f_table:
            f_table[key] = 100/total
        else:
            f_table[key] += 100/total
    
    return f_table

# %%
def display_table(data_list, index):
    table = freq_table(data_list, index)
    table_display = []
    for key in table:
        key_val_as_tuple = (table[key], key)
        table_display.append(key_val_as_tuple)

    table_sorted = sorted(table_display, reverse = True)
    for entry in table_sorted:
        print(entry[1], ':', entry[0])

# %%
display_table(ios_data,11)      # For IOS prime_genres
# Out:
# Games : 58.13664596273457
# Entertainment : 7.888198757764019
# Photo & Video : 4.968944099378889
# Education : 3.66459627329192
# Social Networking : 3.2919254658385046
# Shopping : 2.6086956521739095
# Utilities : 2.5155279503105556
# Sports : 2.14285714285714
# Music : 2.0496894409937862
# Health & Fitness : 2.0186335403726683
# Productivity : 1.7391304347826066
# Lifestyle : 1.5838509316770168
# News : 1.3354037267080732
# Travel : 1.2422360248447193
# Finance : 1.1180124223602474
# Weather : 0.8695652173913038
# Food & Drink : 0.8074534161490678
# Reference : 0.5590062111801242
# Business : 0.5279503105590062
# Book : 0.43478260869565216
# Navigation : 0.18633540372670807
# Medical : 0.18633540372670807
# Catalogs : 0.12422360248447205

# %% [markdown]
# **Android data** has two columns related to the genres of the apps. Let us look at the data in detail.

# %%
display_table(android_data,1)    #For Android 'Categories' column
# Out:
# FAMILY : 18.907942238266926
# GAME : 9.724729241877363
# TOOLS : 8.46119133574016
# BUSINESS : 4.591606498194979
# LIFESTYLE : 3.90342960288811
# PRODUCTIVITY : 3.8921480144404565
# FINANCE : 3.7003610108303455
# MEDICAL : 3.5311371841155417
# SPORTS : 3.3957581227436986
# PERSONALIZATION : 3.3167870036101235
# COMMUNICATION : 3.2378158844765483
# HEALTH_AND_FITNESS : 3.079873646209398
# PHOTOGRAPHY : 2.944494584837555
# NEWS_AND_MAGAZINES : 2.7978339350180583
# SOCIAL : 2.6624548736462152
# TRAVEL_AND_LOCAL : 2.335288808664261
# SHOPPING : 2.2450361010830324
# BOOKS_AND_REFERENCE : 2.14350180505415
# DATING : 1.861462093862813
# VIDEO_PLAYERS : 1.7937725631768928
# MAPS_AND_NAVIGATION : 1.398916967509025
# FOOD_AND_DRINK : 1.2409747292418778
# EDUCATION : 1.1620036101083042
# ENTERTAINMENT : 0.9589350180505433
# LIBRARIES_AND_DEMO : 0.9363718411552363
# AUTO_AND_VEHICLES : 0.9250902527075828
# HOUSE_AND_HOME : 0.8235559566787015
# WEATHER : 0.8009927797833946
# EVENTS : 0.7107400722021667
# PARENTING : 0.6543321299638993
# ART_AND_DESIGN : 0.6430505415162459
# COMICS : 0.6204873646209389
# BEAUTY : 0.5979241877256319

# %%
display_table(android_data,9)    #For Android 'Genres' column
# Out:
# Tools : 8.449909747292507
# Entertainment : 6.069494584837599
# Education : 5.34747292418777
# Business : 4.591606498194979
# Productivity : 3.8921480144404565
# Lifestyle : 3.8921480144404565
# Finance : 3.7003610108303455
# Medical : 3.5311371841155417
# Sports : 3.46344765342962
# Personalization : 3.3167870036101235
# Communication : 3.2378158844765483
# Action : 3.1024368231047053
# Health & Fitness : 3.079873646209398
# Photography : 2.944494584837555
# News & Magazines : 2.7978339350180583
# Social : 2.6624548736462152
# Travel & Local : 2.3240072202166075
# Shopping : 2.2450361010830324
# Books & Reference : 2.14350180505415
# Simulation : 2.041967509025268
# Dating : 1.861462093862813
# Arcade : 1.8501805054151597
# Video Players & Editors : 1.771209386281586
# Casual : 1.7599277978339327
# Maps & Navigation : 1.398916967509025
# Food & Drink : 1.2409747292418778
# Puzzle : 1.1281588447653441
# Racing : 0.9927797833935037
# Role Playing : 0.9363718411552363
# Libraries & Demo : 0.9363718411552363
# Auto & Vehicles : 0.9250902527075828
# Strategy : 0.9138086642599293
# House & Home : 0.8235559566787015
# Weather : 0.8009927797833946
# Events : 0.7107400722021667
# Adventure : 0.6768953068592063
# Comics : 0.6092057761732854
# Beauty : 0.5979241877256319
# Art & Design : 0.5979241877256319
# Parenting : 0.4963898916967507
# Card : 0.451263537906137
# Casino : 0.42870036101083014
# Trivia : 0.4174187725631767
# Educational;Education : 0.3948555956678699
# Board : 0.38357400722021645
# Educational : 0.372292418772563
# Education;Education : 0.33844765342960276
# Word : 0.2594765342960288
# Casual;Pretend Play : 0.23691335740072195
# Music : 0.20306859205776168
# Racing;Action & Adventure : 0.1692238267148014
# Puzzle;Brain Games : 0.1692238267148014
# Entertainment;Music & Video : 0.1692238267148014
# Casual;Brain Games : 0.13537906137184114
# Casual;Action & Adventure : 0.13537906137184114
# Arcade;Action & Adventure : 0.12409747292418771
# Action;Action & Adventure : 0.10153429602888087
# Educational;Pretend Play : 0.09025270758122744
# Simulation;Action & Adventure : 0.07897111913357402
# Parenting;Education : 0.07897111913357402
# Entertainment;Brain Games : 0.07897111913357402
# Board;Brain Games : 0.07897111913357402
# Parenting;Music & Video : 0.06768953068592058
# Educational;Brain Games : 0.06768953068592058
# Casual;Creativity : 0.06768953068592058
# Art & Design;Creativity : 0.06768953068592058
# Education;Pretend Play : 0.05640794223826715
# Role Playing;Pretend Play : 0.04512635379061372
# Education;Creativity : 0.04512635379061372
# Role Playing;Action & Adventure : 0.03384476534296029
# Puzzle;Action & Adventure : 0.03384476534296029
# Entertainment;Creativity : 0.03384476534296029
# Entertainment;Action & Adventure : 0.03384476534296029
# Educational;Creativity : 0.03384476534296029
# Educational;Action & Adventure : 0.03384476534296029
# Education;Music & Video : 0.03384476534296029
# Education;Brain Games : 0.03384476534296029
# Education;Action & Adventure : 0.03384476534296029
# Adventure;Action & Adventure : 0.03384476534296029
# Video Players & Editors;Music & Video : 0.02256317689530686
# Sports;Action & Adventure : 0.02256317689530686
# Simulation;Pretend Play : 0.02256317689530686
# Puzzle;Creativity : 0.02256317689530686
# Music;Music & Video : 0.02256317689530686
# Entertainment;Pretend Play : 0.02256317689530686
# Casual;Education : 0.02256317689530686
# Board;Action & Adventure : 0.02256317689530686
# Video Players & Editors;Creativity : 0.01128158844765343
# Trivia;Education : 0.01128158844765343
# Travel & Local;Action & Adventure : 0.01128158844765343
# Tools;Education : 0.01128158844765343
# Strategy;Education : 0.01128158844765343
# Strategy;Creativity : 0.01128158844765343
# Strategy;Action & Adventure : 0.01128158844765343
# Simulation;Education : 0.01128158844765343
# Role Playing;Brain Games : 0.01128158844765343
# Racing;Pretend Play : 0.01128158844765343
# Puzzle;Education : 0.01128158844765343
# Parenting;Brain Games : 0.01128158844765343
# Music & Audio;Music & Video : 0.01128158844765343
# Lifestyle;Pretend Play : 0.01128158844765343
# Lifestyle;Education : 0.01128158844765343
# Health & Fitness;Education : 0.01128158844765343
# Health & Fitness;Action & Adventure : 0.01128158844765343
# Entertainment;Education : 0.01128158844765343
# Communication;Creativity : 0.01128158844765343
# Comics;Creativity : 0.01128158844765343
# Casual;Music & Video : 0.01128158844765343
# Card;Action & Adventure : 0.01128158844765343
# Books & Reference;Education : 0.01128158844765343
# Art & Design;Pretend Play : 0.01128158844765343
# Art & Design;Action & Adventure : 0.01128158844765343
# Arcade;Pretend Play : 0.01128158844765343
# Adventure;Education : 0.01128158844765343

# %% [markdown]
# The 'Genres' column seems a bit more granular than the 'Categories' column, though it is not very useful for us as it classifies sub-categories of Games and Education genres separately.Hence we'll use the 'Categories' column for further analysis.
#
# **Observation:** The above data indicates the types of apps that are available in the IOS and Android markets. From the looks of it, The IOS app market is dominated by games genre with entertainment apps as the runner ups wheres the android apps are developed both for entertainment and practical purposes.
#
# #### 3.2. Ranking with respect to Average Number of Users
# Although we have a feel for the types of apps out there, the data above doesn't necesssarily correspond to the popularity of these genres. So we will look at the average number of ratings for IOS and average installs for Android markets to get a feel for number of users.
#
# As the number of installs in the Android data has a format like: '1,000,000,000+', we will need to remove any '+' and ',' characters before turning them into numbers. Since we don't know the exact number of installs from this format, the numbers we are going to use are going to be approximate.

# %%
def avg_user_cnt(data_list,genre_index,n_user_index):

    genres = freq_table(data_list,genre_index)
    avg_n_users = []

    for each_genre in genres:
        total_n_users = 0
        len_genre = 0
        for each_row in data_list[1:]:
            genre = each_row[genre_index]
            if genre == each_genre :
                n_users = each_row[n_user_index]
                if('+'in n_users):
                    n_users = n_users.replace('+','')
                if(','in n_users):
                    n_users = n_users.replace(',','')
               
                total_n_users += float(n_users)
                len_genre += 1
        avg_n_users.append([(total_n_users/len_genre),each_genre])        

    sorted_avg_n_users = sorted(avg_n_users, reverse = True)
    for each_entry in sorted_avg_n_users:
        print (format(each_entry[0],'.3e'),each_entry[1])
    return sorted_avg_n_users

# %%
ios_avg_n_users = avg_user_cnt(ios_data,11,5)
# Out:
# 8.609e+04 Navigation
# 7.494e+04 Reference
# 7.155e+04 Social Networking
# 5.733e+04 Music
# 5.228e+04 Weather
# 3.976e+04 Book
# 3.333e+04 Food & Drink
# 3.147e+04 Finance
# 2.844e+04 Photo & Video
# 2.824e+04 Travel
# 2.692e+04 Shopping
# 2.330e+04 Health & Fitness
# 2.301e+04 Sports
# 2.281e+04 Games
# 2.125e+04 News
# 2.103e+04 Productivity
# 1.868e+04 Utilities
# 1.649e+04 Lifestyle
# 1.403e+04 Entertainment
# 7.491e+03 Business
# 7.004e+03 Education
# 4.004e+03 Catalogs
# 6.120e+02 Medical

# %%
android_avg_n_users = avg_user_cnt(android_data,1,5)        # based on Android 'Category' column
# Out:
# 3.846e+07 COMMUNICATION
# 2.473e+07 VIDEO_PLAYERS
# 2.325e+07 SOCIAL
# 1.784e+07 PHOTOGRAPHY
# 1.679e+07 PRODUCTIVITY
# 1.559e+07 GAME
# 1.398e+07 TRAVEL_AND_LOCAL
# 1.164e+07 ENTERTAINMENT
# 1.080e+07 TOOLS
# 9.549e+06 NEWS_AND_MAGAZINES
# 8.768e+06 BOOKS_AND_REFERENCE
# 7.037e+06 SHOPPING
# 5.201e+06 PERSONALIZATION
# 5.074e+06 WEATHER
# 4.189e+06 HEALTH_AND_FITNESS
# 4.057e+06 MAPS_AND_NAVIGATION
# 3.696e+06 FAMILY
# 3.639e+06 SPORTS
# 1.986e+06 ART_AND_DESIGN
# 1.925e+06 FOOD_AND_DRINK
# 1.833e+06 EDUCATION
# 1.712e+06 BUSINESS
# 1.438e+06 LIFESTYLE
# 1.388e+06 FINANCE
# 1.332e+06 HOUSE_AND_HOME
# 8.540e+05 DATING
# 8.177e+05 COMICS
# 6.473e+05 AUTO_AND_VEHICLES
# 6.385e+05 LIBRARIES_AND_DEMO
# 5.426e+05 PARENTING
# 5.132e+05 BEAUTY
# 2.535e+05 EVENTS
# 1.206e+05 MEDICAL

# %% [markdown]
# **Observation** When we rank the apps with respect to their average number of users, we see the picture changes. The games are no longer at the top of the list but we see more of genres like social networking and communication.
#
# #### 3.3. Top Contributors per Genre
#
# Let us look at the topmost contributors per Genre to see what kind of apps are popular within a genre. Let us also look at their histograms so that we have a feel for the distribution and see whether the data is skewed.

# %%
def top_apps(data_list,ranking_list, top_n, name_index, genre_index, n_users_index):

    for each_genre in ranking_list:
        genre = each_genre[1]
        genre_apps = []
        bin_list = [10**x for x in range(0,10)]
        genre_histo = [[x,0] for x in bin_list]
        max_users = 1e20
        
        for each_row in data_list[1:]:
            if (each_row[genre_index] == genre):
                n_users = each_row[n_users_index]
                n_users = n_users.replace('+','')
                n_users = float(n_users.replace(',',''))
                app_name = each_row[name_index]
                genre_apps.append([n_users,app_name])
        
                for bin_index in range(0,len(bin_list)):
                    current_bin = bin_list[bin_index]
                    if(bin_index < (len(bin_list)-1)):
                        next_bin = bin_list[bin_index+1] 
                    else:
                        next_bin = max_users

                    if(current_bin <= n_users) and (n_users < next_bin):
                            genre_histo[bin_index][1] += 1
                        
                    
        top_apps = sorted(genre_apps, reverse = True)
        if (len(top_apps) < top_n):
            top = len(top_apps)
        else:
            top = top_n
            
        print('\n',genre,'-Top',top)
        for rank in range(0,top):
            print (format(top_apps[rank][0],'.2e'),top_apps[rank][1])
               
        print('\n',genre,'-Histo')
        for each_bin in genre_histo:
            print(format(each_bin[0],'.2e'),each_bin[1])

# %%
top_apps(ios_data,ios_avg_n_users,10,1,11,5)
# Out:
#  Navigation -Top 6
# 3.45e+05 Waze - GPS Navigation, Maps & Real-time Traffic
# 1.55e+05 Google Maps - Navigation & Transit
# 1.28e+04 Geocaching®
# 3.58e+03 CoPilot GPS – Car Navigation & Offline Maps
# 1.87e+02 ImmobilienScout24: Real Estate Search in Germany
# 5.00e+00 Railway Route Search
#
#  Navigation -Histo
# 1.00e+00 1
# 1.00e+01 0
# 1.00e+02 1
# 1.00e+03 1
# 1.00e+04 1
# 1.00e+05 2
# 1.00e+06 0
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  Reference -Top 10
# 9.86e+05 Bible
# 2.00e+05 Dictionary.com Dictionary & Thesaurus
# 5.42e+04 Dictionary.com Dictionary & Thesaurus for iPad
# 2.68e+04 Google Translate
# 1.84e+04 Muslim Pro: Ramadan 2017 Prayer Times, Azan, Quran
# 1.76e+04 New Furniture Mods - Pocket Wiki & Game Tools for Minecraft PC Edition
# 1.68e+04 Merriam-Webster Dictionary
# 1.21e+04 Night Sky
# 8.54e+03 City Maps for Minecraft PE - The Best Maps for Minecraft Pocket Edition (MCPE)
# 4.69e+03 LUCKY BLOCK MOD ™ for Minecraft PC Edition - The Best Pocket Wiki & Mods Installer Tools
#
#  Reference -Histo
# 1.00e+00 1
# 1.00e+01 1
# 1.00e+02 3
# 1.00e+03 3
# 1.00e+04 6
# 1.00e+05 2
# 1.00e+06 0
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  Social Networking -Top 10
# 2.97e+06 Facebook
# 1.06e+06 Pinterest
# 3.74e+05 Skype for iPhone
# 3.51e+05 Messenger
# 3.34e+05 Tumblr
# 2.88e+05 WhatsApp Messenger
# 2.61e+05 Kik
# 1.78e+05 ooVoo – Free Video Call, Text and Voice
# 1.65e+05 TextNow - Unlimited Text + Calls
# 1.64e+05 Viber Messenger – Text & Call
#
#  Social Networking -Histo
# 1.00e+00 1
# 1.00e+01 4
# 1.00e+02 26
# 1.00e+03 25
# 1.00e+04 34
# 1.00e+05 9
# 1.00e+06 2
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  Music -Top 10
# 1.13e+06 Pandora - Music & Radio
# 8.79e+05 Spotify Music
# 4.03e+05 Shazam - Discover music, artists, videos & lyrics
# 2.93e+05 iHeartRadio – Free Music & Radio Stations
# 1.36e+05 SoundCloud - Music & Audio
# 1.32e+05 Magic Piano by Smule
# 1.19e+05 Smule Sing!
# 1.10e+05 TuneIn Radio - MLB NBA Audiobooks Podcasts Music
# 1.06e+05 Amazon Music
# 8.26e+04 SoundHound Song Search & Music Player
#
#  Music -Histo
# 1.00e+00 0
# 1.00e+01 5
# 1.00e+02 15
# 1.00e+03 21
# 1.00e+04 15
# 1.00e+05 8
# 1.00e+06 1
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  Weather -Top 10
# 4.96e+05 The Weather Channel: Forecast, Radar & Alerts
# 2.09e+05 The Weather Channel App for iPad – best local forecast, radar map, and storm tracking
# 1.89e+05 WeatherBug - Local Weather, Radar, Maps, Alerts
# 1.50e+05 MyRadar NOAA Weather Radar Forecast
# 1.44e+05 AccuWeather - Weather for Life
# 1.13e+05 Yahoo Weather
# 4.92e+04 Weather Underground: Custom Forecast & Local Radar
# 4.57e+04 NOAA Weather Radar - Weather Forecast & HD Radar
# 3.57e+04 Weather Live Free - Weather Forecast & Alerts
# 2.28e+04 Storm Radar
#
#  Weather -Histo
# 1.00e+00 0
# 1.00e+01 9
# 1.00e+02 3
# 1.00e+03 3
# 1.00e+04 4
# 1.00e+05 6
# 1.00e+06 0
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  Book -Top 10
# 2.52e+05 Kindle – Read eBooks, Magazines & Textbooks
# 1.05e+05 Audible – audio books, original series & podcasts
# 8.41e+04 Color Therapy Adult Coloring Book for Adults
# 6.54e+04 OverDrive – Library eBooks and Audiobooks
# 4.78e+04 HOOKED - Chat Stories
# 8.79e+02 BookShout: Read eBooks & Track Your Reading Goals
# 4.51e+02 Dr. Seuss Treasury — 50 best kids books
# 3.92e+02 Green Riding Hood
# 1.97e+02 Weirdwood Manor
# 9.00e+00 MangaZERO - comic reader
#
#  Book -Histo
# 1.00e+00 1
# 1.00e+01 0
# 1.00e+02 4
# 1.00e+03 0
# 1.00e+04 3
# 1.00e+05 2
# 1.00e+06 0
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  Food & Drink -Top 10
# 3.04e+05 Starbucks
# 2.59e+05 Domino's Pizza USA
# 1.14e+05 OpenTable - Restaurant Reservations
# 1.09e+05 Allrecipes Dinner Spinner
# 2.59e+04 DoorDash - Food Delivery
# 1.79e+04 UberEATS: Uber for Food Delivery
# 9.52e+03 Postmates - Food Delivery, Faster
# 9.07e+03 Dunkin' Donuts - Get Offers, Coupons & Rewards
# 5.66e+03 Chick-fil-A
# 4.05e+03 McDonald's
#
#  Food & Drink -Histo
# 1.00e+00 3
# 1.00e+01 4
# 1.00e+02 5
# 1.00e+03 8
# 1.00e+04 2
# 1.00e+05 4
# 1.00e+06 0
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  Finance -Top 10
# 2.33e+05 Chase Mobile℠
# 2.33e+05 Mint: Personal Finance, Budget, Bills & Money
# 1.20e+05 Bank of America - Mobile Banking
# 1.19e+05 PayPal - Send and request money safely
# 1.02e+05 Credit Karma: Free Credit Scores, Reports & Alerts
# 5.61e+04 Capital One Mobile
# 4.88e+04 Citi Mobile®
# 4.31e+04 Wells Fargo Mobile
# 3.43e+04 Chase Mobile
# 2.38e+04 Square Cash - Send Money for Free
#
#  Finance -Histo
# 1.00e+00 2
# 1.00e+01 6
# 1.00e+02 4
# 1.00e+03 7
# 1.00e+04 10
# 1.00e+05 5
# 1.00e+06 0
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  Photo & Video -Top 10
# 2.16e+06 Instagram
# 3.24e+05 Snapchat
# 2.78e+05 YouTube - Watch Videos, Music, and Live Streams
# 1.23e+05 Pic Collage - Picture Editor & Photo Collage Maker
# 1.23e+05 Funimate video editor: add cool effects to videos
# 1.05e+05 musical.ly - your video social network
# 9.38e+04 Photo Collage Maker & Photo Editor - Live Collage
# 9.04e+04 Vine Camera
# 8.87e+04 Google Photos - unlimited photo and video storage
# 7.99e+04 Flipagram
#
#  Photo & Video -Histo
# 1.00e+00 7
# 1.00e+01 12
# 1.00e+02 31
# 1.00e+03 56
# 1.00e+04 39
# 1.00e+05 5
# 1.00e+06 1
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  Travel -Top 10
# 4.46e+05 Google Earth
# 2.24e+05 Yelp - Nearby Restaurants, Shopping & Services
# 1.46e+05 GasBuddy
# 5.62e+04 TripAdvisor Hotels Flights Restaurants
# 4.95e+04 Uber
# 4.69e+04 Lyft
# 3.23e+04 HotelTonight - Great Deals on Last Minute Hotels
# 3.13e+04 Hotels & Vacation Rentals by Booking.com
# 3.06e+04 Southwest Airlines
# 2.23e+04 Airbnb
#
#  Travel -Histo
# 1.00e+00 1
# 1.00e+01 2
# 1.00e+02 15
# 1.00e+03 8
# 1.00e+04 8
# 1.00e+05 3
# 1.00e+06 0
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  Shopping -Top 10
# 4.18e+05 Groupon - Deals, Coupons & Discount Shopping App
# 2.62e+05 eBay: Best App to Buy, Sell, Save! Online Shopping
# 1.42e+05 Wish - Shopping Made Fun
# 1.31e+05 shopkick - Shopping Rewards & Discounts
# 1.26e+05 Amazon App: shop, scan, compare, and read reviews
# 1.08e+05 Target
# 1.04e+05 Zappos: shop shoes & clothes, fast free shipping
# 8.89e+04 Walgreens – Pharmacy, Photo, Coupons and Shopping
# 8.04e+04 Best Buy
# 7.03e+04 Walmart: Free 2-Day Shipping,* Easy Store Shopping
#
#  Shopping -Histo
# 1.00e+00 1
# 1.00e+01 7
# 1.00e+02 15
# 1.00e+03 24
# 1.00e+04 27
# 1.00e+05 7
# 1.00e+06 0
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  Health & Fitness -Top 10
# 5.08e+05 Calorie Counter & Diet Tracker by MyFitnessPal
# 3.74e+05 Lose It! – Weight Loss Program and Calorie Counter
# 1.37e+05 Weight Watchers
# 1.05e+05 Sleep Cycle alarm clock
# 9.05e+04 Fitbit
# 5.36e+04 Period Tracker Lite
# 3.40e+04 Nike+ Training Club - Workouts & Fitness Plans
# 2.74e+04 Plant Nanny - Water Reminder with Cute Plants
# 1.68e+04 Sworkit - Custom Workouts for Exercise & Fitness
# 1.34e+04 Clue Period Tracker: Period & Ovulation Tracker
#
#  Health & Fitness -Histo
# 1.00e+00 3
# 1.00e+01 6
# 1.00e+02 13
# 1.00e+03 24
# 1.00e+04 9
# 1.00e+05 4
# 1.00e+06 0
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  Sports -Top 10
# 2.91e+05 ESPN: Get scores, news, alerts & watch live sports
# 1.91e+05 Yahoo Fantasy Sports
# 1.60e+05 WatchESPN
# 1.48e+05 The Masters Tournament
# 1.38e+05 Yahoo Sports - Teams, Scores, News & Highlights
# 6.49e+04 ESPN Fantasy Football Baseball Basketball Hockey
# 5.96e+04 CBS Sports App - Sports Scores, News, Stats, Watch
# 5.75e+04 FOX Sports Mobile
# 5.42e+04 2016 U.S. Open Golf Championship
# 4.72e+04 NBC Sports
#
#  Sports -Histo
# 1.00e+00 2
# 1.00e+01 10
# 1.00e+02 17
# 1.00e+03 13
# 1.00e+04 19
# 1.00e+05 5
# 1.00e+06 0
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  Games -Top 10
# 2.13e+06 Clash of Clans
# 1.72e+06 Temple Run
# 9.62e+05 Candy Crush Saga
# 8.24e+05 Angry Birds
# 7.06e+05 Subway Surfers
# 6.79e+05 Solitaire
# 6.77e+05 CSR Racing
# 6.69e+05 Crossy Road - Endless Arcade Hopper
# 6.13e+05 Injustice: Gods Among Us
# 5.67e+05 Hay Day
#
#  Games -Histo
# 1.00e+00 65
# 1.00e+01 263
# 1.00e+02 551
# 1.00e+03 501
# 1.00e+04 307
# 1.00e+05 107
# 1.00e+06 2
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  News -Top 10
# 3.54e+05 Twitter
# 1.33e+05 Fox News
# 1.13e+05 CNN: Breaking US & World News, Live Video
# 6.76e+04 Reddit Official App: All That's Trending and Viral
# 6.17e+04 USA TODAY
# 4.84e+04 ABC News - US & World News + Live Video
# 3.29e+04 NBC News
# 2.91e+04 HuffPost - News, Politics & Entertainment
# 1.86e+04 The Washington Post Classic
# 1.21e+04 WIRED Magazine
#
#  News -Histo
# 1.00e+00 0
# 1.00e+01 6
# 1.00e+02 15
# 1.00e+03 7
# 1.00e+04 8
# 1.00e+05 3
# 1.00e+06 0
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  Productivity -Top 10
# 1.61e+05 Evernote - stay organized
# 1.36e+05 Gmail - email by Google: secure, fast & organized
# 1.23e+05 iTranslate - Language Translator & Dictionary
# 1.14e+05 Yahoo Mail - Keeps You Organized!
# 6.43e+04 Google Docs
# 5.93e+04 Google Drive - free online storage
# 4.96e+04 Dropbox
# 4.80e+04 Microsoft Word
# 3.96e+04 Microsoft OneNote
# 3.28e+04 Microsoft Outlook - email and calendar
#
#  Productivity -Histo
# 1.00e+00 0
# 1.00e+01 4
# 1.00e+02 10
# 1.00e+03 13
# 1.00e+04 22
# 1.00e+05 4
# 1.00e+06 0
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  Utilities -Top 10
# 4.79e+05 Google – Search made just for mobile
# 1.30e+05 Flashlight Ⓞ
# 1.27e+05 My Verizon
# 1.09e+05 myAT&T
# 9.92e+04 The Calculator - Free and Easy Calculating!
# 6.50e+04 Speedtest by Ookla
# 5.58e+04 Google Chrome – The Fast and Secure Web Browser
# 5.45e+04 Alarm Clock HD Free - Digital Alarm Clock Display
# 4.78e+04 Calculator Pro for iPad Free - Smart Calculator
# 3.80e+04 Bitmoji - Your Personal Emoji
#
#  Utilities -Histo
# 1.00e+00 1
# 1.00e+01 14
# 1.00e+02 18
# 1.00e+03 22
# 1.00e+04 15
# 1.00e+05 4
# 1.00e+06 0
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  Lifestyle -Top 10
# 3.43e+05 Zillow Real Estate - Homes for Sale & for Rent
# 1.43e+05 Tinder
# 1.00e+05 Text Free: Free Texting + Calling + MMS
# 6.05e+04 Countdown‼ (Event Reminders and Timer)
# 4.98e+04 PINK Nation
# 2.05e+04 happn — Dating app — Find and meet your crush
# 1.95e+04 Perfect365 - Custom makeup designs and beauty tips
# 1.75e+04 ipsy - Makeup, subscription and beauty tips
# 1.25e+04 cute icon&wallpaper dressup - CocoPPa
# 1.01e+04 Bumble – Find a Date, Meet Friends & Network
#
#  Lifestyle -Histo
# 1.00e+00 1
# 1.00e+01 6
# 1.00e+02 15
# 1.00e+03 17
# 1.00e+04 7
# 1.00e+05 3
# 1.00e+06 0
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  Entertainment -Top 10
# 3.09e+05 Netflix
# 2.92e+05 Fandango Movies - Times + Tickets
# 2.48e+05 Colorfy: Coloring Book for Adults
# 1.83e+05 IMDb Movies & TV - Trailers and Showtimes
# 1.71e+05 TRUTH or DARE!!! - FREE
# 1.18e+05 Mad Libs
# 1.10e+05 Twitch
# 1.01e+05 Action Movie FX
# 9.88e+04 Voice Changer Plus
# 9.83e+04 iFunny :)
#
#  Entertainment -Histo
# 1.00e+00 5
# 1.00e+01 31
# 1.00e+02 76
# 1.00e+03 78
# 1.00e+04 47
# 1.00e+05 8
# 1.00e+06 0
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  Business -Top 10
# 3.87e+04 Indeed Job Search
# 2.47e+04 Flashlight ◎
# 2.01e+04 Adobe Acrobat Reader: View, Create, & Convert PDFs
# 1.17e+04 Scanner App - PDF Document Scan
# 8.62e+03 SayHi Translate
# 8.32e+03 ADP Mobile Solutions
# 7.91e+03 Sideline - 2nd Phone Number
# 3.29e+03 Uber Driver
# 1.15e+03 AirWatch Agent
# 8.81e+02 VPN Go - Safe Fast & Stable VPN Proxy
#
#  Business -Histo
# 1.00e+00 0
# 1.00e+01 3
# 1.00e+02 5
# 1.00e+03 5
# 1.00e+04 4
# 1.00e+05 0
# 1.00e+06 0
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  Education -Top 10
# 1.63e+05 Duolingo - Learn Spanish, French and more
# 1.23e+05 Guess My Age  Math Magic
# 9.65e+04 Lumosity - Brain Training
# 5.81e+04 Elevate - Brain Training and Games
# 4.64e+04 Fit Brains Trainer
# 3.54e+04 ClassDojo
# 2.04e+04 Memrise: learn languages
# 2.03e+04 Peak - Brain Training
# 2.00e+04 Canvas by Instructure
# 1.87e+04 ABCmouse.com - Early Learning Academy
#
#  Education -Histo
# 1.00e+00 8
# 1.00e+01 20
# 1.00e+02 32
# 1.00e+03 36
# 1.00e+04 13
# 1.00e+05 2
# 1.00e+06 0
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  Catalogs -Top 4
# 1.33e+04 CPlus for Craigslist app - mobile classifieds
# 2.03e+03 DRAGONS MODS FREE for Minecraft PC Game Edition
# 4.31e+02 Face Swap and Copy Free – Switch & Fusion Faces in a Photo
# 2.13e+02 Ringtone Remixes - Marimba Remix Ringtones
#
#  Catalogs -Histo
# 1.00e+00 0
# 1.00e+01 0
# 1.00e+02 2
# 1.00e+03 1
# 1.00e+04 1
# 1.00e+05 0
# 1.00e+06 0
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  Medical -Top 6
# 1.34e+03 SnoreLab : Record Your Snoring
# 1.20e+03 Blink Health
# 1.10e+03 Complete Anatomy
# 2.90e+01 MyDx One: Find a Strain that Works for You
# 0.00e+00 iSleeping by iSommeil SARL
# 0.00e+00 Malodo : Stop au mal de dos
#
#  Medical -Histo
# 1.00e+00 0
# 1.00e+01 1
# 1.00e+02 0
# 1.00e+03 3
# 1.00e+04 0
# 1.00e+05 0
# 1.00e+06 0
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0

# %%
top_apps(android_data,android_avg_n_users,10,0,1,5)
# Out:
#  COMMUNICATION -Top 10
# 1.00e+09 WhatsApp Messenger
# 1.00e+09 Skype - free IM & video calls
# 1.00e+09 Messenger – Text and Video Chat for Free
# 1.00e+09 Hangouts
# 1.00e+09 Google Chrome: Fast & Secure
# 1.00e+09 Gmail
# 5.00e+08 imo free video calls and chat
# 5.00e+08 Viber Messenger
# 5.00e+08 UC Browser - Fast Download Private & Secure
# 5.00e+08 LINE: Free Calls & Messages
#
#  COMMUNICATION -Histo
# 1.00e+00 3
# 1.00e+01 19
# 1.00e+02 36
# 1.00e+03 35
# 1.00e+04 30
# 1.00e+05 25
# 1.00e+06 62
# 1.00e+07 50
# 1.00e+08 21
# 1.00e+09 6
#
#  VIDEO_PLAYERS -Top 10
# 1.00e+09 YouTube
# 1.00e+09 Google Play Movies & TV
# 5.00e+08 MX Player
# 1.00e+08 VivaVideo - Video Editor & Photo Movie
# 1.00e+08 VideoShow-Video Editor, Video Maker, Beauty Camera
# 1.00e+08 VLC for Android
# 1.00e+08 Motorola Gallery
# 1.00e+08 Motorola FM Radio
# 1.00e+08 Dubsmash
# 5.00e+07 Vote for
#
#  VIDEO_PLAYERS -Histo
# 1.00e+00 0
# 1.00e+01 2
# 1.00e+02 13
# 1.00e+03 22
# 1.00e+04 21
# 1.00e+05 16
# 1.00e+06 40
# 1.00e+07 36
# 1.00e+08 7
# 1.00e+09 2
#
#  SOCIAL -Top 10
# 1.00e+09 Instagram
# 1.00e+09 Google+
# 1.00e+09 Facebook
# 5.00e+08 Snapchat
# 5.00e+08 Facebook Lite
# 1.00e+08 VK
# 1.00e+08 Tumblr
# 1.00e+08 Tik Tok - including musical.ly
# 1.00e+08 Tango - Live Video Broadcast
# 1.00e+08 Pinterest
#
#  SOCIAL -Histo
# 1.00e+00 4
# 1.00e+01 13
# 1.00e+02 22
# 1.00e+03 33
# 1.00e+04 28
# 1.00e+05 35
# 1.00e+06 52
# 1.00e+07 35
# 1.00e+08 10
# 1.00e+09 3
#
#  PHOTOGRAPHY -Top 10
# 1.00e+09 Google Photos
# 1.00e+08 Z Camera - Photo Editor, Beauty Selfie, Collage
# 1.00e+08 YouCam Perfect - Selfie Photo Editor
# 1.00e+08 YouCam Makeup - Magic Selfie Makeovers
# 1.00e+08 Sweet Selfie - selfie camera, beauty cam, photo edit
# 1.00e+08 S Photo Editor - Collage Maker , Photo Collage
# 1.00e+08 Retrica
# 1.00e+08 PicsArt Photo Studio: Collage Maker & Pic Editor
# 1.00e+08 PhotoGrid: Video & Pic Collage Maker, Photo Editor
# 1.00e+08 Photo Editor Pro
#
#  PHOTOGRAPHY -Histo
# 1.00e+00 1
# 1.00e+01 3
# 1.00e+02 17
# 1.00e+03 19
# 1.00e+04 19
# 1.00e+05 30
# 1.00e+06 74
# 1.00e+07 79
# 1.00e+08 18
# 1.00e+09 1
#
#  PRODUCTIVITY -Top 10
# 1.00e+09 Google Drive
# 5.00e+08 Microsoft Word
# 5.00e+08 Google Calendar
# 5.00e+08 Dropbox
# 5.00e+08 Cloud Print
# 1.00e+08 WPS Office - Word, Docs, PDF, Note, Slide & Sheet
# 1.00e+08 SwiftKey Keyboard
# 1.00e+08 Samsung Notes
# 1.00e+08 Microsoft PowerPoint
# 1.00e+08 Microsoft Outlook
#
#  PRODUCTIVITY -Histo
# 1.00e+00 6
# 1.00e+01 30
# 1.00e+02 44
# 1.00e+03 41
# 1.00e+04 33
# 1.00e+05 44
# 1.00e+06 77
# 1.00e+07 48
# 1.00e+08 21
# 1.00e+09 1
#
#  GAME -Top 10
# 1.00e+09 Subway Surfers
# 5.00e+08 Temple Run 2
# 5.00e+08 Pou
# 5.00e+08 My Talking Tom
# 5.00e+08 Candy Crush Saga
# 1.00e+08 slither.io
# 1.00e+08 Zombie Tsunami
# 1.00e+08 Yes day
# 1.00e+08 Vector
# 1.00e+08 Trivia Crack
#
#  GAME -Histo
# 1.00e+00 2
# 1.00e+01 24
# 1.00e+02 28
# 1.00e+03 40
# 1.00e+04 85
# 1.00e+05 152
# 1.00e+06 241
# 1.00e+07 231
# 1.00e+08 58
# 1.00e+09 1
#
#  TRAVEL_AND_LOCAL -Top 10
# 1.00e+09 Maps - Navigate & Explore
# 1.00e+09 Google Street View
# 1.00e+08 TripAdvisor Hotels Flights Restaurants Attractions
# 1.00e+08 Google Earth
# 1.00e+08 Booking.com Travel Deals
# 5.00e+07 trivago: Hotels & Travel
# 5.00e+07 VZ Navigator
# 5.00e+07 MAPS.ME – Offline Map and Travel Navigation
# 5.00e+07 2GIS: directory & navigator
# 1.00e+07 easyJet: Travel App
#
#  TRAVEL_AND_LOCAL -Histo
# 1.00e+00 4
# 1.00e+01 3
# 1.00e+02 20
# 1.00e+03 28
# 1.00e+04 34
# 1.00e+05 25
# 1.00e+06 60
# 1.00e+07 28
# 1.00e+08 3
# 1.00e+09 2
#
#  ENTERTAINMENT -Top 10
# 1.00e+08 Talking Ben the Dog
# 1.00e+08 Talking Angela
# 1.00e+08 Netflix
# 1.00e+08 IMDb Movies & TV
# 1.00e+08 Hotstar
# 5.00e+07 Twitch: Livestream Multiplayer Games & Esports
# 5.00e+07 Talking Ginger 2
# 5.00e+07 PlayStation App
# 5.00e+07 Amazon Prime Video
# 1.00e+07 ivi - movies and TV shows in HD
#
#  ENTERTAINMENT -Histo
# 1.00e+00 0
# 1.00e+01 0
# 1.00e+02 0
# 1.00e+03 0
# 1.00e+04 2
# 1.00e+05 10
# 1.00e+06 44
# 1.00e+07 24
# 1.00e+08 5
# 1.00e+09 0
#
#  TOOLS -Top 10
# 1.00e+09 Google
# 5.00e+08 Security Master - Antivirus, VPN, AppLock, Booster
# 5.00e+08 SHAREit - Transfer & Share
# 5.00e+08 Google Translate
# 5.00e+08 Gboard - the Google Keyboard
# 5.00e+08 Clean Master- Space Cleaner & Antivirus
# 1.00e+08 Tiny Flashlight + LED
# 1.00e+08 Speedtest by Ookla
# 1.00e+08 Share Music & Transfer Files - Xender
# 1.00e+08 Samsung Smart Switch Mobile
#
#  TOOLS -Histo
# 1.00e+00 8
# 1.00e+01 31
# 1.00e+02 73
# 1.00e+03 111
# 1.00e+04 132
# 1.00e+05 121
# 1.00e+06 139
# 1.00e+07 106
# 1.00e+08 28
# 1.00e+09 1
#
#  NEWS_AND_MAGAZINES -Top 10
# 1.00e+09 Google News
# 5.00e+08 Twitter
# 5.00e+08 Flipboard: News For Our Time
# 5.00e+07 Dailyhunt (Newshunt) - Latest News, Viral Videos
# 1.00e+07 detikcom - Latest & Most Complete News
# 1.00e+07 Updates for Samsung - Android Update Versions
# 1.00e+07 Topbuzz: Breaking News, Videos & Funny GIFs
# 1.00e+07 SmartNews: Breaking News Headlines
# 1.00e+07 Reddit: Social News, Trending Memes & Funny Videos
# 1.00e+07 Read- Latest News, Information, Gossip and Politics
#
#  NEWS_AND_MAGAZINES -Histo
# 1.00e+00 2
# 1.00e+01 17
# 1.00e+02 28
# 1.00e+03 41
# 1.00e+04 43
# 1.00e+05 33
# 1.00e+06 59
# 1.00e+07 21
# 1.00e+08 2
# 1.00e+09 1
#
#  BOOKS_AND_REFERENCE -Top 10
# 1.00e+09 Google Play Books
# 1.00e+08 Wattpad 📖 Free Books
# 1.00e+08 Bible
# 1.00e+08 Audiobooks from Audible
# 1.00e+08 Amazon Kindle
# 1.00e+07 Wikipedia
# 1.00e+07 Spanish English Translator
# 1.00e+07 Quran for Android
# 1.00e+07 Oxford Dictionary of English : Free
# 1.00e+07 NOOK: Read eBooks & Magazines
#
#  BOOKS_AND_REFERENCE -Histo
# 1.00e+00 4
# 1.00e+01 6
# 1.00e+02 13
# 1.00e+03 44
# 1.00e+04 34
# 1.00e+05 36
# 1.00e+06 29
# 1.00e+07 19
# 1.00e+08 4
# 1.00e+09 1
#
#  SHOPPING -Top 10
# 1.00e+08 eBay: Buy & Sell this Summer - Discover Deals Now!
# 1.00e+08 Wish - Shopping Made Fun
# 1.00e+08 Flipkart Online Shopping App
# 1.00e+08 Amazon Shopping
# 1.00e+08 AliExpress - Smarter Shopping, Better Living
# 5.00e+07 letgo: Buy & Sell Used Stuff, Cars & Real Estate
# 5.00e+07 The birth
# 5.00e+07 OLX - Buy and Sell
# 5.00e+07 Myntra Online Shopping App
# 5.00e+07 Mercado Libre: Find your favorite brands
#
#  SHOPPING -Histo
# 1.00e+00 1
# 1.00e+01 8
# 1.00e+02 19
# 1.00e+03 13
# 1.00e+04 14
# 1.00e+05 38
# 1.00e+06 53
# 1.00e+07 48
# 1.00e+08 5
# 1.00e+09 0
#
#  PERSONALIZATION -Top 10
# 1.00e+08 ZEDGE™ Ringtones & Wallpapers
# 1.00e+08 Parallel Space - Multiple accounts & Two face
# 1.00e+08 Hola Launcher- Theme,Wallpaper
# 1.00e+08 GO Launcher - 3D parallax Themes & HD Wallpapers
# 1.00e+08 GO Keyboard - Emoticon keyboard, Free Theme, GIF
# 1.00e+08 CM Launcher 3D - Theme, Wallpapers, Efficient
# 1.00e+08 Backgrounds HD (Wallpapers)
# 1.00e+08 APUS Launcher - Theme, Wallpaper, Hide Apps
# 5.00e+07 ZenUI Launcher
# 5.00e+07 Yandex Browser with Protect
#
#  PERSONALIZATION -Histo
# 1.00e+00 4
# 1.00e+01 16
# 1.00e+02 40
# 1.00e+03 40
# 1.00e+04 46
# 1.00e+05 40
# 1.00e+06 63
# 1.00e+07 37
# 1.00e+08 8
# 1.00e+09 0
#
#  WEATHER -Top 10
# 5.00e+07 Weather & Clock Widget for Android
# 5.00e+07 The Weather Channel: Rain Forecast & Storm Alerts
# 5.00e+07 GO Weather - Widget, Theme, Wallpaper, Efficient
# 5.00e+07 AccuWeather: Daily Forecast & Live Weather Reports
# 1.00e+07 wetter.com - Weather and Radar
# 1.00e+07 Yandex.Weather
# 1.00e+07 Yahoo Weather
# 1.00e+07 Weather –Simple weather forecast
# 1.00e+07 Weather by WeatherBug: Forecast, Radar & Alerts
# 1.00e+07 Weather 14 Days
#
#  WEATHER -Histo
# 1.00e+00 0
# 1.00e+01 2
# 1.00e+02 1
# 1.00e+03 4
# 1.00e+04 4
# 1.00e+05 18
# 1.00e+06 28
# 1.00e+07 14
# 1.00e+08 0
# 1.00e+09 0
#
#  HEALTH_AND_FITNESS -Top 10
# 5.00e+08 Samsung Health
# 1.00e+08 Period Tracker - Period Calendar Ovulation Tracker
# 5.00e+07 Calorie Counter - MyFitnessPal
# 1.00e+07 Workout Trainer: fitness coach
# 1.00e+07 Water Drink Reminder
# 1.00e+07 Strava Training: Track Running, Cycling & Swimming
# 1.00e+07 Step Counter - Pedometer Free & Calorie Counter
# 1.00e+07 Six Pack in 30 Days - Abs Workout
# 1.00e+07 Runtastic Running App & Mile Tracker
# 1.00e+07 Runkeeper - GPS Track Run Walk
#
#  HEALTH_AND_FITNESS -Histo
# 1.00e+00 4
# 1.00e+01 23
# 1.00e+02 30
# 1.00e+03 22
# 1.00e+04 26
# 1.00e+05 56
# 1.00e+06 78
# 1.00e+07 32
# 1.00e+08 2
# 1.00e+09 0
#
#  MAPS_AND_NAVIGATION -Top 10
# 1.00e+08 Waze - GPS, Maps, Traffic Alerts & Live Navigation
# 1.00e+08 Uber
# 5.00e+07 GPS Navigation & Offline Maps Sygic
# 5.00e+07 Free GPS Navigation
# 1.00e+07 Yandex.Transport
# 1.00e+07 Yahoo! transit guide free timetable, operation information, transfer search
# 1.00e+07 TomTom GPS Navigation Traffic
# 1.00e+07 Subway Terminator: Smarter Subway
# 1.00e+07 Moovit: Bus Time & Train Time Live Info
# 1.00e+07 Maps, GPS Navigation & Directions, Street View
#
#  MAPS_AND_NAVIGATION -Histo
# 1.00e+00 0
# 1.00e+01 4
# 1.00e+02 9
# 1.00e+03 23
# 1.00e+04 20
# 1.00e+05 14
# 1.00e+06 40
# 1.00e+07 12
# 1.00e+08 2
# 1.00e+09 0
#
#  FAMILY -Top 10
# 1.00e+09 Google Play Games
# 1.00e+08 Where's My Water? Free
# 1.00e+08 Tom Loves Angela
# 1.00e+08 Talking Tom Cat 2
# 1.00e+08 Talking Tom Cat
# 1.00e+08 Talking Tom & Ben News
# 1.00e+08 Talking Ginger
# 1.00e+08 ROBLOX
# 1.00e+08 Minion Rush: Despicable Me Official Game
# 1.00e+08 Hay Day
#
#  FAMILY -Histo
# 1.00e+00 10
# 1.00e+01 70
# 1.00e+02 158
# 1.00e+03 281
# 1.00e+04 274
# 1.00e+05 325
# 1.00e+06 365
# 1.00e+07 178
# 1.00e+08 13
# 1.00e+09 1
#
#  SPORTS -Top 10
# 1.00e+08 FIFA Soccer
# 1.00e+08 3D Bowling
# 5.00e+07 Wrestling Revolution 3D
# 5.00e+07 Top Eleven 2018 - Be a Soccer Manager
# 5.00e+07 NFL
# 5.00e+07 NBA LIVE Mobile Basketball
# 5.00e+07 EA SPORTS UFC®
# 5.00e+07 Cricbuzz - Live Cricket Scores & News
# 5.00e+07 3D Tennis
# 1.00e+07 theScore: Live Sports Scores, News, Stats & Videos
#
#  SPORTS -Histo
# 1.00e+00 11
# 1.00e+01 26
# 1.00e+02 29
# 1.00e+03 20
# 1.00e+04 46
# 1.00e+05 52
# 1.00e+06 75
# 1.00e+07 40
# 1.00e+08 2
# 1.00e+09 0
#
#  ART_AND_DESIGN -Top 10
# 5.00e+07 Sketch - Draw & Paint
# 1.00e+07 ibis Paint X
# 1.00e+07 Textgram - write on photos
# 1.00e+07 Tattoo Name On My Photo Editor
# 1.00e+07 Canva: Poster, banner, card maker & graphic design
# 5.00e+06 U Launcher Lite – FREE Live Cool Themes, Hide Apps
# 5.00e+06 Floor Plan Creator
# 5.00e+06 FlipaClip - Cartoon animation
# 1.00e+06 Text on Photo - Fonteee
# 1.00e+06 Name Art Photo Editor - Focus n Filters
#
#  ART_AND_DESIGN -Histo
# 1.00e+00 0
# 1.00e+01 0
# 1.00e+02 1
# 1.00e+03 5
# 1.00e+04 16
# 1.00e+05 22
# 1.00e+06 7
# 1.00e+07 5
# 1.00e+08 0
# 1.00e+09 0
#
#  FOOD_AND_DRINK -Top 10
# 1.00e+07 foodpanda - Local Food Delivery
# 1.00e+07 Zomato - Restaurant Finder and Food Delivery App
# 1.00e+07 Uber Eats: Local Food Delivery
# 1.00e+07 Tastely
# 1.00e+07 Starbucks
# 1.00e+07 Pizza Hut
# 1.00e+07 McDonald's - McDonald's Japan
# 1.00e+07 McDonald's
# 1.00e+07 Foursquare City Guide
# 1.00e+07 Domino's Pizza USA
#
#  FOOD_AND_DRINK -Histo
# 1.00e+00 3
# 1.00e+01 8
# 1.00e+02 7
# 1.00e+03 3
# 1.00e+04 15
# 1.00e+05 25
# 1.00e+06 36
# 1.00e+07 13
# 1.00e+08 0
# 1.00e+09 0
#
#  EDUCATION -Top 10
# 1.00e+07 Remind: School Communication
# 1.00e+07 Quizlet: Learn Languages & Vocab with Flashcards
# 1.00e+07 Math Tricks
# 1.00e+07 Lumosity: #1 Brain Games & Cognitive Training App
# 1.00e+07 Learn languages, grammar & vocabulary with Memrise
# 1.00e+07 Learn English with Wlingua
# 1.00e+07 Google Classroom
# 1.00e+07 ClassDojo
# 5.00e+06 Rosetta Stone: Learn to Speak & Read New Languages
# 5.00e+06 NeuroNation - Focus and Brain Training
#
#  EDUCATION -Histo
# 1.00e+00 0
# 1.00e+01 0
# 1.00e+02 0
# 1.00e+03 0
# 1.00e+04 11
# 1.00e+05 31
# 1.00e+06 53
# 1.00e+07 8
# 1.00e+08 0
# 1.00e+09 0
#
#  BUSINESS -Top 10
# 1.00e+08 OfficeSuite : Free Office + PDF Editor
# 1.00e+08 File Commander - File Manager/Explorer
# 5.00e+07 Vault-Hide SMS,Pics & Videos,App Lock,Cloud backup
# 5.00e+07 Secure Folder
# 5.00e+07 Indeed Job Search
# 5.00e+07 Facebook Pages Manager
# 5.00e+07 Docs To Go™ Free Office Suite
# 1.00e+07 ZOOM Cloud Meetings
# 1.00e+07 Visual Voicemail by MetroPCS
# 1.00e+07 Uber Driver
#
#  BUSINESS -Histo
# 1.00e+00 22
# 1.00e+01 64
# 1.00e+02 96
# 1.00e+03 64
# 1.00e+04 55
# 1.00e+05 36
# 1.00e+06 49
# 1.00e+07 18
# 1.00e+08 2
# 1.00e+09 0
#
#  LIFESTYLE -Top 10
# 1.00e+08 Tinder
# 5.00e+07 Samsung+
# 1.00e+07 metroZONE
# 1.00e+07 iHoroscope - 2018 Daily Horoscope & Astrology
# 1.00e+07 happn – Local dating app
# 1.00e+07 Zara
# 1.00e+07 Timely Alarm Clock
# 1.00e+07 Talking Babsy Baby: Baby Games
# 1.00e+07 Sleep as Android: Sleep cycle tracker, smart alarm
# 1.00e+07 Rate Guide Bill Letter
#
#  LIFESTYLE -Histo
# 1.00e+00 5
# 1.00e+01 28
# 1.00e+02 57
# 1.00e+03 60
# 1.00e+04 59
# 1.00e+05 55
# 1.00e+06 59
# 1.00e+07 22
# 1.00e+08 1
# 1.00e+09 0
#
#  FINANCE -Top 10
# 1.00e+08 Google Pay
# 5.00e+07 PayPal
# 1.00e+07 İşCep
# 1.00e+07 Wells Fargo Mobile
# 1.00e+07 Mobile Bancomer
# 1.00e+07 K PLUS
# 1.00e+07 Itau bank
# 1.00e+07 HDFC Bank MobileBanking
# 1.00e+07 Credit Karma
# 1.00e+07 Chase Mobile
#
#  FINANCE -Histo
# 1.00e+00 2
# 1.00e+01 9
# 1.00e+02 34
# 1.00e+03 55
# 1.00e+04 84
# 1.00e+05 51
# 1.00e+06 78
# 1.00e+07 14
# 1.00e+08 1
# 1.00e+09 0
#
#  HOUSE_AND_HOME -Top 10
# 1.00e+07 tinyCam Monitor FREE
# 1.00e+07 Zillow: Find Houses for Sale & Apartments for Rent
# 1.00e+07 Trulia Real Estate & Rentals
# 1.00e+07 Realtor.com Real Estate: Homes for Sale and Rent
# 1.00e+07 Houzz Interior Design Ideas
# 5.00e+06 Trulia Rent Apartments & Homes
# 5.00e+06 Real Estate sale & rent Trovit
# 5.00e+06 DaBang - Rental Homes in Korea
# 5.00e+06 Alfred Home Security Camera
# 1.00e+06 realestate.com.au - Buy, Rent & Sell Property
#
#  HOUSE_AND_HOME -Histo
# 1.00e+00 1
# 1.00e+01 2
# 1.00e+02 4
# 1.00e+03 4
# 1.00e+04 9
# 1.00e+05 23
# 1.00e+06 25
# 1.00e+07 5
# 1.00e+08 0
# 1.00e+09 0
#
#  DATING -Top 10
# 1.00e+07 Zoosk Dating App: Meet Singles
# 1.00e+07 OkCupid Dating
# 1.00e+07 Moco - Chat, Meet People
# 1.00e+07 Match™ Dating - Meet Singles
# 1.00e+07 Hot or Not - Find someone right now
# 1.00e+07 Hitwe - meet people and chat
# 1.00e+07 Find Real Love — YouLove Premium Dating
# 1.00e+07 Chat Rooms, Avatars, Date - Galaxy
# 5.00e+06 iPair-Meet, Chat, Dating
# 5.00e+06 eharmony - Online Dating App
#
#  DATING -Histo
# 1.00e+00 3
# 1.00e+01 15
# 1.00e+02 26
# 1.00e+03 21
# 1.00e+04 25
# 1.00e+05 42
# 1.00e+06 25
# 1.00e+07 8
# 1.00e+08 0
# 1.00e+09 0
#
#  COMICS -Top 10
# 1.00e+07 LINE WEBTOON - Free Comics
# 5.00e+06 comico Popular Original Cartoon Updated Everyday Comico
# 5.00e+06 Perfect Viewer
# 5.00e+06 Narrator's Voice
# 5.00e+06 Comics
# 1.00e+06 漫咖 Comics - Manga,Novel and Stories
# 1.00e+06 pixiv comic - everyone's manga app
# 1.00e+06 WebComics
# 1.00e+06 Tapas – Comics, Novels, and Stories
# 1.00e+06 Memes Button
#
#  COMICS -Histo
# 1.00e+00 0
# 1.00e+01 1
# 1.00e+02 1
# 1.00e+03 5
# 1.00e+04 17
# 1.00e+05 15
# 1.00e+06 15
# 1.00e+07 1
# 1.00e+08 0
# 1.00e+09 0
#
#  AUTO_AND_VEHICLES -Top 10
# 1.00e+07 AutoScout24 - used car finder
# 1.00e+07 Android Auto - Maps, Media, Messaging & Voice
# 5.00e+06 Used cars for sale - Trovit
# 5.00e+06 Ulysse Speedometer
# 5.00e+06 Fines of the State Traffic Safety Inspectorate are official: inspection, payment of fines
# 1.00e+06 ezETC (ETC balance inquiry, meter trial, real-time traffic)
# 1.00e+06 auto fines
# 1.00e+06 Used car search Goo net whole car Go to net
# 1.00e+06 Used car is the first car - used car purchase, used car quotation, dealer information to
# 1.00e+06 Used Cars and Trucks for Sale
#
#  AUTO_AND_VEHICLES -Histo
# 1.00e+00 3
# 1.00e+01 5
# 1.00e+02 8
# 1.00e+03 10
# 1.00e+04 10
# 1.00e+05 28
# 1.00e+06 16
# 1.00e+07 2
# 1.00e+08 0
# 1.00e+09 0
#
#  LIBRARIES_AND_DEMO -Top 10
# 1.00e+07 MX Player Codec (ARMv7)
# 1.00e+07 Cardboard
# 1.00e+07 Aviary Stickers: Free Pack
# 5.00e+06 Wifi Connect Library
# 5.00e+06 Aviary Effects: Classic
# 1.00e+06 Wifi Test
# 1.00e+06 OpenCV Manager
# 1.00e+06 New Ringtones 2018
# 1.00e+06 Market Update Helper
# 1.00e+06 ES Chromecast plugin
#
#  LIBRARIES_AND_DEMO -Histo
# 1.00e+00 0
# 1.00e+01 1
# 1.00e+02 4
# 1.00e+03 19
# 1.00e+04 26
# 1.00e+05 20
# 1.00e+06 10
# 1.00e+07 3
# 1.00e+08 0
# 1.00e+09 0
#
#  PARENTING -Top 10
# 1.00e+07 Pregnancy Tracker & Countdown to Baby Due Date
# 5.00e+06 My baby Piano
# 1.00e+06 Vegetable Fun
# 1.00e+06 Urban Limo Taxi Simulator
# 1.00e+06 Safe365 – Cell Phone GPS Locator For Your Family
# 1.00e+06 My baby firework
# 1.00e+06 My baby Phone
# 1.00e+06 My baby Game (Balloon POP!)
# 1.00e+06 Feed Baby - Baby Tracker
# 1.00e+06 Family Album Mitene: Private Photo & Video Sharing
#
#  PARENTING -Histo
# 1.00e+00 0
# 1.00e+01 1
# 1.00e+02 0
# 1.00e+03 3
# 1.00e+04 20
# 1.00e+05 19
# 1.00e+06 14
# 1.00e+07 1
# 1.00e+08 0
# 1.00e+09 0
#
#  BEAUTY -Top 10
# 1.00e+07 Beauty Camera - Selfie Camera
# 5.00e+06 Best Hairstyles step by step
# 1.00e+06 ipsy: Makeup, Beauty, and Tips
# 1.00e+06 Ulta Beauty
# 1.00e+06 Sephora: Skin Care, Beauty Makeup & Fragrance Shop
# 1.00e+06 Selfie Camera
# 1.00e+06 Rainbow Camera
# 1.00e+06 Mirror Camera (Mirror + Selfie Camera)
# 1.00e+06 Mirror - Zoom & Exposure -
# 1.00e+06 Filters for Selfie
#
#  BEAUTY -Histo
# 1.00e+00 0
# 1.00e+01 1
# 1.00e+02 6
# 1.00e+03 4
# 1.00e+04 18
# 1.00e+05 14
# 1.00e+06 9
# 1.00e+07 1
# 1.00e+08 0
# 1.00e+09 0
#
#  EVENTS -Top 10
# 5.00e+06 Ticketmaster Event Tickets
# 5.00e+06 StubHub - Tickets to Sports, Concerts & Events
# 1.00e+06 Vivid Seats – Event Tickets
# 1.00e+06 SeatGeek – Tickets to Sports, Concerts, Broadway
# 1.00e+06 Gametime - Tickets to Sports, Concerts, Theater
# 1.00e+06 Fever
# 5.00e+05 Reminder
# 1.00e+05 vide-greniers.org
# 1.00e+05 my4D
# 1.00e+05 Xceed - Clubs, DJs, Festivals & Tickets
#
#  EVENTS -Histo
# 1.00e+00 0
# 1.00e+01 6
# 1.00e+02 17
# 1.00e+03 13
# 1.00e+04 8
# 1.00e+05 13
# 1.00e+06 6
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0
#
#  MEDICAL -Top 10
# 5.00e+06 My Calendar - Period Tracker
# 5.00e+06 Blood Pressure
# 1.00e+06 mySugr: the blood sugar tracker made just for you
# 1.00e+06 Pregnancy Week By Week
# 1.00e+06 Pregnancy Calculator and Tracker app
# 1.00e+06 Ovia Pregnancy Tracker & Baby Countdown Calendar
# 1.00e+06 Ovia Fertility Tracker & Ovulation Calculator
# 1.00e+06 MyChart
# 1.00e+06 GoodRx Drug Prices and Coupons
# 1.00e+06 FollowMyHealth®
#
#  MEDICAL -Histo
# 1.00e+00 12
# 1.00e+01 46
# 1.00e+02 60
# 1.00e+03 61
# 1.00e+04 63
# 1.00e+05 53
# 1.00e+06 18
# 1.00e+07 0
# 1.00e+08 0
# 1.00e+09 0

# %% [markdown]
# ### 4. Recommendations
#
# #### 4.1. IOS Market
# Unfortunately, the IOS sample sizes are very small for the genres with highest average number of users to make a recommendation. It seems like the IOS dataset was already small compared to the Android one. On top of that, it also had a significant number of non-English and paid application data. Since 58% of the final dataset belonged to games genre, the data for the remaining genres are not very reliable.
#
# Within the remaining genres in top 10, social networking and music genres have some relatively significant number of sample size. If I had to pick one, I would recommend the music genre as  it is easier to challenge established apps in this genre. For your app to succeed in social networking genre, you need to attract a significant portion of the user's personal network which is harder than just appeling to the user individually.
#
# #### 4.2. Android Market
# For the Android set we see a reasonable amount of data to look through. From the highest ranking genres, video players look the most reasonable and attractive one to get into as the average number of users is significantly high whereas the number of big players in the genre is rather low. Given the brand names in this dataset seem to have ~1e9,1e8 number of users, I would call any app with more than 1e8 users a big player.
